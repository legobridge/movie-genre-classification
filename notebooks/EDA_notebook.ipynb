# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_data_df = pd.read_csv('../data/processed/train_data_processed.csv')
train_data_df.head()
# Out:
#    id                        title     genre  \
# 0   1       Oscar et la dame rose      drama
# 1   2                       Cupid   thriller
# 2   3   Young, Wild and Wonderful      adult
# 3   4              The Secret Sin      drama
# 4   5             The Unrecovered      drama
#
#                                          description  year  \
# 0   Listening in to a conversation between his do...  2009
# 1   A brother and sister with a past incestuous r...  1997
# 2   As the bus empties the students for their fie...  1980
# 3   To help their unemployed father make ends mee...  1915
# 4   The film's title refers not only to the un-re...  2007
#
#                                  description_stemmed  \
# 0  ['listen', 'convers', 'doctor', 'parent', '10-...
# 1  ['brother', 'sister', 'past', 'incestu', 'rela...
# 2  ['bu', 'empti', 'student', 'field', 'trip', 'm...
# 3  ['help', 'unemploy', 'father', 'make', 'end', ...
# 4  ['film', "'s", 'titl', 'refer', 'un-recov', 'b...
#
#                           description_stemmed_string
# 0  listen convers doctor parent 10-year-old oscar...
# 1  brother sister past incestu relationship curre...
# 2  bu empti student field trip museum natur histo...
# 3  help unemploy father make end meet edith twin ...
# 4  film 's titl refer un-recov bodi ground zero a...

# %%
test_data_df=pd.read_csv("../data/test_data.txt", sep=':::' ,names=["id", "title","description"])
test_datawithsols_df=pd.read_csv("../data/test_data_solution.txt", sep=':::' ,names=["id", "title","genre","description"])
# Out:
# /var/folders/tk/xgt1qkjn2250kh87lr8djx740000gn/T/ipykernel_45203/1851602362.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_data_df=pd.read_csv("../data/test_data.txt", sep=':::' ,names=["id", "title","description"])
# /var/folders/tk/xgt1qkjn2250kh87lr8djx740000gn/T/ipykernel_45203/1851602362.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   test_datawithsols_df=pd.read_csv("../data/test_data_solution.txt", sep=':::' ,names=["id", "title","genre","description"])

# %%
print("Rows in train data",train_data_df.shape[0])
print("Rows in test data", test_data_df.shape[0])
# Out:
# Rows in train data 54214
# Rows in test data 54200

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kushal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
##check for empty values in descriptions and genres
train_data_df.isnull().sum()
# Out:
# id                            0
# title                         0
# genre                         0
# description                   0
# year                          0
# description_stemmed           0
# description_stemmed_string    0
# dtype: int64

# %%
##check for duplicates --> no duplicates
train_data_df.duplicated().sum()
# Out:
# 0

# %%
# test_data_df

# %%
## cleaning genres
# train_data_df['genre'] = train_data_df['genre'].str.strip()
# train_data_df['genre'] = train_data_df['genre'].str.lower()
test_datawithsols_df['genre'] = test_datawithsols_df['genre'].str.strip()
test_datawithsols_df['genre'] = test_datawithsols_df['genre'].str.lower()
test_datawithsols_df.head()
# Out:
#    id                          title        genre  \
# 0   1          Edgar's Lunch (1998)      thriller
# 1   2      La guerra de papá (1977)        comedy
# 2   3   Off the Beaten Track (2010)   documentary
# 3   4        Meu Amigo Hindu (2015)         drama
# 4   5             Er nu zhai (1955)         drama
#
#                                          description
# 0   L.R. Brane loves his life - his car, his apar...
# 1   Spain, March 1964: Quico is a very naughty ch...
# 2   One year in the life of Albin and his family ...
# 3   His father has died, he hasn't spoken with hi...
# 4   Before he was known internationally as a mart...

# %%
## Barplot of genres present in train_data
sns.set_theme(style="whitegrid")
sns.countplot(y=train_data_df['genre'],order = train_data_df['genre'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='genre'>

# %%
## Barplot of genres present in test_data
sns.countplot(y=test_datawithsols_df['genre'],order = test_datawithsols_df['genre'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='genre'>

# %% [markdown]
# ### Cleaning

# %%
## Year column has a lot of non numeric columns --> need to clean these rows
train_data_df['year'].value_counts()
# Out:
# 2016    3048
# 2017    3018
# 2015    2740
# ????    2415
# 2014    2324
#         ...
# 7/XV       1
# nced       1
# 2/VI       1
# 65/I       1
# /XXI       1
# Name: year, Length: 271, dtype: int64

# %%
train_data_df[(train_data_df['year'].str.isnumeric()) | (train_data_df['year']=='????') ].shape
# Out:
# (52285, 7)

# %%
## get index of these clean year columns for later analysis
year_idx = (train_data_df['year'].str.isnumeric()) | (train_data_df['year']=='????')

# %% [markdown]
# ## Getting Insights

# %% [markdown]
# #### Year vs Genre

# %%
## Get top 5 genre counts for each year
count_df = train_data_df[year_idx].groupby(by = ['year','genre'],as_index = False).agg(
Count_of_Genres = pd.NamedAgg(column = 'genre',aggfunc='count')
)
years = train_data_df[year_idx]['year'].unique()
top5genredf = pd.DataFrame(columns=count_df.columns)
for year in years:
    idx = count_df[count_df['year']==year]['Count_of_Genres'].nlargest(5).keys().to_list()
    # print(count_df.iloc[idx])
    # break
    top5genredf = pd.concat([top5genredf,count_df.iloc[idx]],ignore_index=True)
top5genredf = top5genredf.sort_values(by='year')
top5genredf
# Out:
#      year        genre Count_of_Genres
# 553  1894        short               4
# 569  1895        short               2
# 568  1896        short               3
# 567  1897        short               9
# 566  1898        short               4
# ..    ...          ...             ...
# 115  ????        drama             721
# 116  ????       comedy             322
# 117  ????  documentary             222
# 118  ????     thriller             211
# 119  ????       horror             175
#
# [573 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaledcount = []
for year in years:
    res = top5genredf[top5genredf['year']==year][['Count_of_Genres']].apply(lambda x: x / x.max())['Count_of_Genres'].to_list()
    for item in res:
        scaledcount.append(item)
top5genredf['scaled_count']=scaledcount
years_bin = []
count = 0
jump = 50
for i in range(1894,2030,10):
    years_bin.append(str(i))
years_bin
plt.figure(figsize=(20,10))
sns.barplot(x=top5genredf['year'][top5genredf['year'].isin(years_bin)],y=top5genredf['scaled_count'][top5genredf['year'].isin(years_bin)],hue=top5genredf['genre'][top5genredf['year'].isin(years_bin)])
plt.show()

# %% [markdown]
# #### Word Counts - Genre Wise

# %%
train_data_df['genre'].value_counts()
# Out:
# drama          13613
# documentary    13096
# comedy          7447
# short           5073
# horror          2204
# thriller        1591
# action          1315
# western         1032
# reality-tv       884
# family           784
# adventure        775
# music            731
# romance          672
# sci-fi           647
# adult            590
# crime            505
# animation        498
# sport            432
# talk-show        391
# fantasy          323
# mystery          319
# musical          277
# biography        265
# history          243
# game-show        194
# news             181
# war              132
# Name: genre, dtype: int64

# %%
genres = train_data_df['genre'].unique()
genre_word_map = {}
column_to_use = 'description_stemmed'
for genre in genres:
    temp = []
    descriptions = train_data_df[train_data_df['genre']==genre][column_to_use].to_list()
    for item in descriptions:
        wordlist = item.replace('[','').replace(']','').replace("'","").replace('"','').split(',')
        for word in wordlist:
            if word == ' ' or len(word) < 3 or '`' in word:
                continue
            temp.append(word.strip())
    genre_word_map[genre]=temp

# %%
train_data_df.head()
# Out:
#    id                        title     genre  \
# 0   1       Oscar et la dame rose      drama
# 1   2                       Cupid   thriller
# 2   3   Young, Wild and Wonderful      adult
# 3   4              The Secret Sin      drama
# 4   5             The Unrecovered      drama
#
#                                          description  year  \
# 0   Listening in to a conversation between his do...  2009
# 1   A brother and sister with a past incestuous r...  1997
# 2   As the bus empties the students for their fie...  1980
# 3   To help their unemployed father make ends mee...  1915
# 4   The film's title refers not only to the un-re...  2007
#
#                                  description_stemmed  \
# 0  ['listen', 'convers', 'doctor', 'parent', '10-...
# 1  ['brother', 'sister', 'past', 'incestu', 'rela...
# 2  ['bu', 'empti', 'student', 'field', 'trip', 'm...
# 3  ['help', 'unemploy', 'father', 'make', 'end', ...
# 4  ['film', "'s", 'titl', 'refer', 'un-recov', 'b...
#
#                           description_stemmed_string
# 0  listen convers doctor parent 10-year-old oscar...
# 1  brother sister past incestu relationship curre...
# 2  bu empti student field trip museum natur histo...
# 3  help unemploy father make end meet edith twin ...
# 4  film 's titl refer un-recov bodi ground zero a...

# %%
from collections import Counter 
def most_frequent(List,num=5):
    occurence_count = Counter(List)
    return occurence_count.most_common(num)
num=5
for genre in genres:
    print('\n')
    print("For genre ",genre)
    print(str(num)+" Most common terms and their frequencies are ")
    print(most_frequent(genre_word_map[genre],num=num))
# Out:
# For genre  drama
# 5 Most common terms and their frequencies are
# [('life', 6491), ('love', 4887), ('live', 4806), ('one', 4661), ('famili', 4310)]
#
#
# For genre  thriller
# 5 Most common terms and their frequencies are
# [('find', 603), ('one', 555), ('life', 513), ('murder', 479), ('get', 418)]
#
#
# For genre  adult
# 5 Most common terms and their frequencies are
# [('get', 239), ('sex', 225), ('two', 185), ('girl', 178), ('one', 167)]
#
#
# For genre  documentary
# 5 Most common terms and their frequencies are
# [('film', 7492), ('documentari', 4755), ('world', 4690), ('stori', 4563), ('life', 4335)]
#
#
# For genre  comedy
# 5 Most common terms and their frequencies are
# [('get', 2722), ('one', 2140), ('life', 2002), ('friend', 1948), ('find', 1946)]
#
#
# For genre  crime
# 5 Most common terms and their frequencies are
# [('murder', 185), ('polic', 176), ('one', 175), ('crime', 151), ('find', 141)]
#
#
# For genre  reality-tv
# 5 Most common terms and their frequencies are
# [('show', 466), ('one', 292), ('seri', 265), ('new', 260), ('live', 249)]
#
#
# For genre  horror
# 5 Most common terms and their frequencies are
# [('one', 929), ('find', 777), ('friend', 668), ('hous', 631), ('kill', 540)]
#
#
# For genre  sport
# 5 Most common terms and their frequencies are
# [('vs', 353), ('world', 208), ('team', 151), ('championship', 136), ('sport', 129)]
#
#
# For genre  animation
# 5 Most common terms and their frequencies are
# [('world', 171), ('anim', 162), ('friend', 154), ('one', 140), ('adventur', 131)]
#
#
# For genre  action
# 5 Most common terms and their frequencies are
# [('one', 452), ('find', 422), ('get', 378), ('kill', 370), ('life', 331)]
#
#
# For genre  fantasy
# 5 Most common terms and their frequencies are
# [('world', 164), ('one', 121), ('stori', 102), ('find', 102), ('power', 74)]
#
#
# For genre  short
# 5 Most common terms and their frequencies are
# [('film', 2107), ('one', 1510), ('life', 1347), ('stori', 966), ('man', 964)]
#
#
# For genre  sci-fi
# 5 Most common terms and their frequencies are
# [('earth', 254), ('world', 251), ('human', 231), ('one', 208), ('find', 201)]
#
#
# For genre  music
# 5 Most common terms and their frequencies are
# [('music', 670), ('perform', 443), ('show', 349), ('live', 316), ('band', 311)]
#
#
# For genre  adventure
# 5 Most common terms and their frequencies are
# [('find', 248), ('one', 199), ('world', 195), ('take', 191), ('stori', 187)]
#
#
# For genre  talk-show
# 5 Most common terms and their frequencies are
# [('show', 325), ('talk', 150), ('host', 144), ('interview', 110), ('live', 107)]
#
#
# For genre  western
# 5 Most common terms and their frequencies are
# [('gang', 597), ('town', 530), ('kill', 524), ('ranch', 457), ('find', 456)]
#
#
# For genre  family
# 5 Most common terms and their frequencies are
# [('famili', 333), ('new', 226), ('get', 223), ('live', 222), ('show', 217)]
#
#
# For genre  mystery
# 5 Most common terms and their frequencies are
# [('murder', 196), ('mysteri', 143), ('one', 130), ('find', 127), ('man', 106)]
#
#
# For genre  history
# 5 Most common terms and their frequencies are
# [('stori', 107), ('histori', 89), ('war', 85), ('film', 79), ('world', 72)]
#
#
# For genre  news
# 5 Most common terms and their frequencies are
# [('news', 95), ('film', 55), ('show', 52), ('new', 51), ('program', 42)]
#
#
# For genre  biography
# 5 Most common terms and their frequencies are
# [('life', 147), ('film', 146), ('stori', 113), ('one', 84), ('year', 72)]
#
#
# For genre  romance
# 5 Most common terms and their frequencies are
# [('love', 746), ('life', 305), ('get', 285), ('find', 271), ('meet', 255)]
#
#
# For genre  game-show
# 5 Most common terms and their frequencies are
# [('contest', 326), ('answer', 273), ('question', 254), ('team', 245), ('game', 235)]
#
#
# For genre  musical
# 5 Most common terms and their frequencies are
# [('music', 212), ('love', 106), ('film', 91), ('new', 87), ('one', 84)]
#
#
# For genre  war
# 5 Most common terms and their frequencies are
# [('war', 112), ('german', 63), ('armi', 53), ('one', 50), ('battl', 49)]

# %%
from wordcloud import WordCloud
def makewordcloud(wordlist):
    text = ''
    for word in wordlist:
        text+=' '+word
    wordcloud = WordCloud(background_color="white", width=3000, height=2000, max_words=100).generate(text)

    # Display the generated image:
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
def make_histogram(wordlist,num=20):
    elems = most_frequent(wordlist,num)
    x = []
    y = []
    for elem in elems:
        x.append(elem[0])
        y.append(elem[1])
    sns.barplot(y=x,x=y)

# %%
genre = 'war'
makewordcloud(genre_word_map[genre])

# %%
make_histogram(genre_word_map[genre])

# %% [markdown]
# #### Change of using words over the years for a genre

# %%
def wordcloud_over_years(genre,years):
    yearwordmap = {}
    for year in years:
        temp = []
        descriptions = train_data_df[(train_data_df['year']==year) & (train_data_df['genre']==genre)][column_to_use].to_list()
        for item in descriptions:
            wordlist = item.replace('[','').replace(']','').replace("'","").replace('"','').split(',')
            for word in wordlist:
                if word == ' ' or len(word) < 3 or '`' in word:
                    continue
                temp.append(word.strip())
        if len(temp) == 0:
            continue
        print("For year ",year)
        makewordcloud(temp)

# %%
genre = 'drama'
# years_bin = ['2000','2001']
years_bin = []
jump = 20
for i in range(1894,2030,20):
    years_bin.append(str(i))
wordcloud_over_years(genre,years_bin)
# Out:
# For year  1914
# For year  1934
# For year  1954
# For year  1974
# For year  1994
# For year  2014

# %%
years_bin
# Out:
# ['1894', '1914', '1934', '1954', '1974', '1994', '2014']

# %%
# Descriptions with highest word counts
description_word_count_series = train_data_df['description_stemmed_string'].map(lambda x: len(x.split(' ')))
print(description_word_count_series.sort_values(ascending=False))
train_data_df.loc[description_word_count_series.idxmax()].description_stemmed_string
# Out:
# 43784    1492
# 16314    1141
# 2542     1093
# 30193     937
# 25579     811
#          ...
# 30635       6
# 48605       6
# 12361       5
# 52224       5
# 4754        4
# Name: description_stemmed_string, Length: 54214, dtype: int64
# "j'ai réalisé en 2009 un film sur mon pčre intitulé gratien gélina un géant aux pie d'argil grâce aux archiv j'ai pu fair revivr celui que l'on surnommait ťle pčre du théâtre québécoisť il était décédé dix an auparav et dan le derničr anné de sa vie il avait perdu tout contact avec la réalité alor qu'il était encor lucid je n'ai jamai pri le temp de capter sa parol sa réflexion sur la vie en mar 2011 la second épous de mon pčre la comédienn huguett oligni alor âgée de 89 an quittait son appart pour aller vivr en résidenc je connaissai huguett depui prč de 50 an aprč le décč de mčre ell est entré dan vie et au fil du temp j'ai noué avec ell une relat intim et chaleureus je craignai que confronté au déracin de l'entré en résidenc ell perd la forc de vivr au contrair sentant la mort proch belle-mčr ressenti ce passag comm une libérat et sa vision de chose s'est transformé sa parol aussi dégagé de l'autocensur qu'el s'était longtemp imposé d'entré de jeu ell ' fait cett révélation étonnant : ťj'ai passé le temp oů l'on veut tellement paraîtr paraîtr - non c'est fini ça je ne veux plu - quand est jeun c'est trč import mai quand est trč vieux qu'on un pie dan la tomb quasiment paraîtr pour quoi pour qui non paraîtr c'est terminé pour moiť chčre comédienn n'avait plu d'imag ŕ défendr ell était passé de l'autr côté du miroir ell parlait san détour de sa foi de se souffranc passé de se amour mai surtout de son profond goűt de vivr de la sentir serein transparent lumineus ' profondé touché et je sui demandé si ce miracl serait possibl devant une caméra afin que d'autr que moi puissent découvrir le sourir de cell qui ŕ la fin de sa vie se sentait la plu heureus du mond un tournag intim presqu secret alor débuté lor de me visit pendant dix-huit moi j'installai rapid caméra et micro sentant que le temp était compté je m'avançai sur une glace trč minc avec une vieill dame qui avait déjŕ un pie dan l'éternité comprenait-el que je faisai un film cela lui importait peu ell profitait de chaqu instant passé avec moi ell m'aimait comm mčre m'aurait aimé ell m'ouvrait son coeur et j ' découvrai son indéfect amour de la vie malgré le épreuv qui l'avaient marqué pour cett comédienn qui avait souvent incarné de rôle de mčre la maternité était devenu un calvair lorsqu'el avait été privé de se enfant pendant neuf an et cela ell n'en avait jamai parlé publiqu avec l'accord de se enfant ann et jean alexandr j'ai pu révéler un passé famili douloureux qui avait laissé de trace męme s'il était mainten loin derričr ŕ cett quęt intim d'autr voix se sont ajouté cell de son ami d'enfanc l'écrivain marguerit lescop qui ŕ 97 an fait la preuv que l'énergi et la passion n'ont pa d'âge que l'amitié n ' pa de fin cell de françois faucher françois graton janin sutto gill pelleti et gérard poirier qui m'ont rappelé la fragilité du souvenir que laiss un comédien aprč avoir peuplé notr imaginair pendant plu d'un demi-sičcl et combien il n'est pa facil de quitter un métier qui vou passionn toujour durant ce rencontr tourné par mon ami le cinéast françoi laliberté je ressentai une grand fierté de recueillir leur parol fort précise coloré ŕ traver eux j'avai autant l'impress de filmer notr histoir collect que cell de bell huguett durant ce tournag il eu de instant de pur bonheur comm la découvert de cett mélodi composé par andré mathieu pour sa muse huguett il en était tombé amoureux en 1943 et lui avait envoyé une lettr écrite sur une porté qu'el recevrait 65 an plu tard un moment d'émotion rare oů pour la premičr foi grâce au pianist alain lefčvr j'ai pu entendr avec huguett un homm qui dit en note l'amour qu'il pour une femm la vieilless n'est pa toujour triomphant et j'ai voulu la montrer pour ce qu'el est san maquillag pourtant lŕ aussi de miracl se produis aprč avoir résisté de tout son ętre ŕ l'entré en résidenc huguett été conquis par le magnifiqu rocher qu'el voyait de sa fenętr et il est devenu un ami ŕ qui ell parlait tou le jour j'avai en tęte la magnifiqu chans ...

# %% [markdown]
# ## Earlier Preprocessing and WordClouds

# %%
# !pip install wordcloud
from wordcloud import WordCloud

# %%
# train_data_df=pd.read_csv("train_data.txt", sep=':::' ,names=["id", "title","genre","description"])
# test_data_df=pd.read_csv("test_data.txt", sep=':::' ,names=["id", "title","description"])
# test_datawithsols_df=pd.read_csv("test_data_solution.txt", sep=':::' ,names=["id", "title","genre","description"])

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer
import nltk
import re
stop_words = set(stopwords.words("english"))
def removenumbers(list_):
    pattern = '[0-9]'
    list_ = [re.sub(pattern, '', i) for i in list_]
    return list_
def preprocess(text):
    text = text.strip().lower()
    tokenizer = RegexpTokenizer(r'\w+')
    text_tokens = tokenizer.tokenize(text)
    filtered_list = []
    for word in text_tokens:
        if word.casefold() not in stop_words:
            filtered_list.append(word)
    filtered_list = removenumbers(filtered_list)
    filtered_list = [x for x in filtered_list if x != '']
    answer = ''
    for item in filtered_list:
        answer+=item+ ' '
    answer = answer.strip()
    return answer
train_description_text=''
train_descriptions = train_data_df['description'].tolist()
for description in train_descriptions:
    toadd = description
    train_description_text+= toadd + ' '
train_description_text = preprocess(train_description_text)

# %%
train_descriptions[0]
# Out:
# ' Listening in to a conversation between his doctor and parents, 10-year-old Oscar learns what nobody has the courage to tell him. He only has a few weeks to live. Furious, he refuses to speak to anyone except straight-talking Rose, the lady in pink he meets on the hospital stairs. As Christmas approaches, Rose uses her fantastical experiences as a professional wrestler, her imagination, wit and charm to allow Oscar to live life and love to the full, in the company of his friends Pop Corn, Einstein, Bacon and childhood sweetheart Peggy Blue.'

# %%
train_description_text[:200]
# Out:
# 'listening conversation doctor parents year old oscar learns nobody courage tell weeks live furious refuses speak anyone except straight talking rose lady pink meets hospital stairs christmas approache'

# %%
test_description_text=''
test_descriptions = test_datawithsols_df['description'].tolist()
for description in test_descriptions:
    toadd = description
    test_description_text+= toadd + ' '
test_description_text = preprocess(test_description_text)

# %%
def makewordcloud(text):
    wordcloud = WordCloud(background_color="white", width=3000, height=2000, max_words=500).generate(text)

    # Display the generated image:
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
makewordcloud(train_description_text)

# %%
makewordcloud(test_description_text)
